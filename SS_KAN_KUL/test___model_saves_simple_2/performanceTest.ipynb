# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
training_history = pd.read_csv('./SS_KAN_KUL/test___model_saves_simple_2/training_history_Silverbox_state_[2]_output_[2]_batch_128_MLPKAN.csv')

# %%
plt.plot(training_history['time'],training_history['train_R2'])

plt.xlabel('Time (s)')
plt.ylabel('R2 Score')
plt.legend(['Training', 'Testing'])
plt.title('Model Performance Over Time')
plt.show()
