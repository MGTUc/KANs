# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
outputMLPKAN = pd.read_csv('../kan_feynman_results_MLPKAN.csv')
outputMLPKANtorch = pd.read_csv('../kan_feynman_results_MLPKANtorch.csv')
outputefficientKAN = pd.read_csv('../kan_feynman_results_efficientKAN.csv')
outputMLP = pd.read_csv('../kan_feynman_results_MLP.csv')
outputFastMLPKAN = pd.read_csv('../kan_feynman_results_FastMLPKAN.csv')

# %%
high_r2MLPKAN = outputMLPKAN[outputMLPKAN['R2 Score'] > 0.99]
print(high_r2MLPKAN.shape[0])
print(outputMLPKAN['R2 Score'].mean())

high_r2MLPKANtorch = outputMLPKANtorch[outputMLPKANtorch['R2 Score'] > 0.99]
print(high_r2MLPKANtorch.shape[0])
print(outputMLPKANtorch['R2 Score'].mean())

high_r2efficientKAN = outputefficientKAN[outputefficientKAN['R2 Score'] > 0.99]
print(high_r2efficientKAN.shape[0])
print(outputefficientKAN['R2 Score'].mean())

high_r2MLP = outputMLP[outputMLP['R2 Score'] > 0.99]
print(high_r2MLP.shape[0])
print(outputMLP['R2 Score'].mean())

high_r2FastMLPKAN = outputFastMLPKAN[outputFastMLPKAN['R2 Score'] > 0.99]
print(high_r2FastMLPKAN.shape[0])
print(outputFastMLPKAN['R2 Score'].mean())
# Out:
# 13
# 0.9466959155839065
# 16
# 0.9516314514752092
# 25
# 0.9831306667163454
# 19
# 0.981501330589426
# 21
# 0.9554221506776481

# %%
print(high_r2MLPKAN['time'].mean())
print(high_r2MLPKANtorch['time'].mean())
print(high_r2efficientKAN['KAN time'].mean())
print(high_r2MLP['time'].mean())
print(high_r2FastMLPKAN['time'].mean())
# Out:
# 6.155864199990622
# 3.0809598124978947
# 2.7008753519970923
# 1.0458657947417938
# 1.8134062381051037

# %%
plt.figure(figsize=(10, 6))
plt.boxplot([high_r2MLPKAN['time'],high_r2FastMLPKAN['time'], high_r2efficientKAN['KAN time'], high_r2MLP['time']], 
            labels=['MLPKAN','FastMLPKAN', 'Efficient KAN', 'MLP'])
plt.ylabel('Time (seconds)')
plt.title('Time to achieve R2 Score > 0.99')
plt.grid(True, which="both", ls="--")
plt.show()
# Out:
# C:\Users\Maarten\AppData\Local\Temp\ipykernel_4800\833785079.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([high_r2MLPKAN['time'],high_r2FastMLPKAN['time'], high_r2efficientKAN['KAN time'], high_r2MLP['time'], high_r2FastMLPKAN['time']],
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 plt.boxplot([high_r2MLPKAN['time'],high_r2FastMLPKAN['time'], high_r2efficientKAN['KAN time'], high_r2MLP['time'], high_r2FastMLPKAN['time']],
#       3             labels=['MLPKAN','FastMLPKAN', 'Efficient KAN', 'MLP'])
#       4 plt.ylabel('Time (seconds)')
#       5 plt.title('Time to achieve R2 Score > 0.99')
#
# File c:\Users\Maarten\codeProjects\MLenv\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\Maarten\codeProjects\MLenv\Lib\site-packages\matplotlib\_api\deprecation.py:295, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     290     warn_deprecated(
#     291         since, message=f"The {old!r} parameter of {func.__name__}() "
#     292         f"has been renamed {new!r} since Matplotlib {since}; support "
#     293         f"for the old name will be dropped in %(removal)s.")
#     294     kwargs[new] = kwargs.pop(old)
# --> 295 return func(*args, **kwargs)
#
# File c:\Users\Maarten\codeProjects\MLenv\Lib\site-packages\matplotlib\pyplot.py:3086, in boxplot(x, notch, sym, vert, orientation, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, tick_labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, label, data)
#    3052 @_copy_docstring_and_deprecators(Axes.boxplot)
#    3053 def boxplot(
#    3054     x: ArrayLike | Sequence[ArrayLike],
#    (...)   3084     data=None,
#    3085 ) -> dict[str, Any]:
# -> 3086     return gca().boxplot(
#    3087         x,
#    3088         notch=notch,
#    3089         sym=sym,
#    3090         vert=vert,
#    3091         orientation=orientation,
#    3092         whis=whis,
#    3093         positions=positions,
#    3094         widths=widths,
#    3095         patch_artist=patch_artist,
#    3096         bootstrap=bootstrap,
#    3097         usermedians=usermedians,
#    3098         conf_intervals=conf_intervals,
#    3099         meanline=meanline,
#    3100         showmeans=showmeans,
#    3101         showcaps=showcaps,
#    3102         showbox=showbox,
#    3103         showfliers=showfliers,
#    3104         boxprops=boxprops,
#    3105         tick_labels=tick_labels,
#    3106         flierprops=flierprops,
#    3107         medianprops=medianprops,
#    3108         meanprops=meanprops,
#    3109         capprops=capprops,
#    3110         whiskerprops=whiskerprops,
#    3111         manage_ticks=manage_ticks,
#    3112         autorange=autorange,
#    3113         zorder=zorder,
#    3114         capwidths=capwidths,
#    3115         label=label,
#    3116         **({"data": data} if data is not None else {}),
#    3117     )
#
# File c:\Users\Maarten\codeProjects\MLenv\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File c:\Users\Maarten\codeProjects\MLenv\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Maarten\codeProjects\MLenv\Lib\site-packages\matplotlib\_api\deprecation.py:295, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     290     warn_deprecated(
#     291         since, message=f"The {old!r} parameter of {func.__name__}() "
#     292         f"has been renamed {new!r} since Matplotlib {since}; support "
#     293         f"for the old name will be dropped in %(removal)s.")
#     294     kwargs[new] = kwargs.pop(old)
# --> 295 return func(*args, **kwargs)
#
# File c:\Users\Maarten\codeProjects\MLenv\Lib\site-packages\matplotlib\axes\_axes.py:4138, in Axes.boxplot(self, x, notch, sym, vert, orientation, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, tick_labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, label)
#    4135 if bootstrap is None:
#    4136     bootstrap = mpl.rcParams['boxplot.bootstrap']
# -> 4138 bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    4139                                labels=tick_labels, autorange=autorange)
#    4140 if notch is None:
#    4141     notch = mpl.rcParams['boxplot.notch']
#
# File c:\Users\Maarten\codeProjects\MLenv\Lib\site-packages\matplotlib\cbook.py:1217, in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1215     labels = itertools.repeat(None)
#    1216 elif len(labels) != ncols:
# -> 1217     raise ValueError("Dimensions of labels and X must be compatible")
#    1219 input_whis = whis
#    1220 for ii, (x, label) in enumerate(zip(X, labels)):
#    1221
#    1222     # empty dict
#
# ValueError: Dimensions of labels and X must be compatible
